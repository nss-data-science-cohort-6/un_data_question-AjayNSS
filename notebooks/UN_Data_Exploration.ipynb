# %%
#3
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#4
gdp_df = pd.read_csv('../data/gdp_per_capita.csv')

# %%
gdp_df.head(10)
# Out:
#   Country or Area  Year        Value  Value Footnotes
# 0     Afghanistan  2019  2065.036398              NaN
# 1     Afghanistan  2018  2033.779002              NaN
# 2     Afghanistan  2017  2058.383832              NaN
# 3     Afghanistan  2016  2057.062164              NaN
# 4     Afghanistan  2015  2068.265904              NaN
# 5     Afghanistan  2014  2102.385234              NaN
# 6     Afghanistan  2013  2116.465454              NaN
# 7     Afghanistan  2012  2075.491747              NaN
# 8     Afghanistan  2011  1904.559799              NaN
# 9     Afghanistan  2010  1957.029338              NaN

# %%
gdp_df.tail(5)
# Out:
#      Country or Area                                      Year        Value  \
# 6865        Zimbabwe                                      1992  3054.889178
# 6866        Zimbabwe                                      1991  3426.598094
# 6867        Zimbabwe                                      1990  3324.348171
# 6868   footnoteSeqID                                  Footnote          NaN
# 6869               2  Excludes South Sudan after July 9, 2011.          NaN
#
#       Value Footnotes
# 6865              NaN
# 6866              NaN
# 6867              NaN
# 6868              NaN
# 6869              NaN

# %%
#5
gdp_df.drop("Value Footnotes", axis=1, inplace=True)

# %%
gdp_df
# Out:
#      Country or Area                                      Year        Value
# 0        Afghanistan                                      2019  2065.036398
# 1        Afghanistan                                      2018  2033.779002
# 2        Afghanistan                                      2017  2058.383832
# 3        Afghanistan                                      2016  2057.062164
# 4        Afghanistan                                      2015  2068.265904
# ...              ...                                       ...          ...
# 6865        Zimbabwe                                      1992  3054.889178
# 6866        Zimbabwe                                      1991  3426.598094
# 6867        Zimbabwe                                      1990  3324.348171
# 6868   footnoteSeqID                                  Footnote          NaN
# 6869               2  Excludes South Sudan after July 9, 2011.          NaN
#
# [6870 rows x 3 columns]

# %%
gdp_df.rename(columns = {'Country or Area':'Country', 'Year':'Year', 'Value': 'GDP_Per_Capita'}, inplace = True)

# %%
#6
gdp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6870 entries, 0 to 6869
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country         6870 non-null   object
#  1   Year            6870 non-null   object
#  2   GDP_Per_Capita  6868 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 161.1+ KB

# %%
gdp_df.dtypes
# Out:
# Country            object
# Year               object
# GDP_Per_Capita    float64
# dtype: object

# %%
 gdp_df.drop(6869)
# Out:
#             Country      Year  GDP_Per_Capita
# 0       Afghanistan      2019     2065.036398
# 1       Afghanistan      2018     2033.779002
# 2       Afghanistan      2017     2058.383832
# 3       Afghanistan      2016     2057.062164
# 4       Afghanistan      2015     2068.265904
# ...             ...       ...             ...
# 6864       Zimbabwe      1993     3033.504852
# 6865       Zimbabwe      1992     3054.889178
# 6866       Zimbabwe      1991     3426.598094
# 6867       Zimbabwe      1990     3324.348171
# 6868  footnoteSeqID  Footnote             NaN
#
# [6869 rows x 3 columns]

# %%
gdp_df = gdp_df.drop(6868)

# %%
gdp_df = gdp_df.drop(6869)

# %%
gdp_df["Country"] = gdp_df["Country"].astype('string')
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 6863       Zimbabwe
# 6864       Zimbabwe
# 6865       Zimbabwe
# 6866       Zimbabwe
# 6867       Zimbabwe
# Name: Country, Length: 6868, dtype: string

# %%
gdp_df
# Out:
#           Country  Year  GDP_Per_Capita
# 0     Afghanistan  2019     2065.036398
# 1     Afghanistan  2018     2033.779002
# 2     Afghanistan  2017     2058.383832
# 3     Afghanistan  2016     2057.062164
# 4     Afghanistan  2015     2068.265904
# ...           ...   ...             ...
# 6863     Zimbabwe  1994     3263.934978
# 6864     Zimbabwe  1993     3033.504852
# 6865     Zimbabwe  1992     3054.889178
# 6866     Zimbabwe  1991     3426.598094
# 6867     Zimbabwe  1990     3324.348171
#
# [6868 rows x 3 columns]

# %%
gdp_df = gdp_df.astype({"Country": 'string' , 'Year': int})

# %%
gdp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6868 entries, 0 to 6867
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country         6868 non-null   string
#  1   Year            6868 non-null   int32
#  2   GDP_Per_Capita  6868 non-null   float64
# dtypes: float64(1), int32(1), string(1)
# memory usage: 187.8 KB

# %%
# Ques 7
print(gdp_df.groupby(['Year'])['Year'].count())

#Obs: It increased every year until 2013 stated contact till 2017 and dropped after that
# Out:
# Year
# 1990    207
# 1991    208
# 1992    209
# 1993    212
# 1994    214
# 1995    221
# 1996    221
# 1997    223
# 1998    223
# 1999    224
# 2000    231
# 2001    232
# 2002    233
# 2003    233
# 2004    234
# 2005    234
# 2006    235
# 2007    235
# 2008    235
# 2009    236
# 2010    236
# 2011    237
# 2012    237
# 2013    238
# 2014    238
# 2015    238
# 2016    238
# 2017    238
# 2018    237
# 2019    231
# Name: Year, dtype: int64

# %%
#Ques 8

#print(gdp_df.Country.unique())
print(gdp_df.groupby(["Country"])["Country"].count().to_string())
# Out:
# Country
# Afghanistan                                          18
# Albania                                              30
# Algeria                                              30
# Angola                                               30
# Antigua and Barbuda                                  30
# Arab World                                           30
# Argentina                                            30
# Armenia                                              30
# Aruba                                                28
# Australia                                            30
# Austria                                              30
# Azerbaijan                                           30
# Bahrain                                              30
# Bangladesh                                           30
# Barbados                                             30
# Belarus                                              30
# Belgium                                              30
# ...

# %%
#Ques 8, Which countries are least represented in the dataset 
gdp_df
#print(gdp_df["Country"].value_counts(ascending=False).reset_index().to_string())
# Out:
#           Country  Year  GDP_Per_Capita
# 0     Afghanistan  2019     2065.036398
# 1     Afghanistan  2018     2033.779002
# 2     Afghanistan  2017     2058.383832
# 3     Afghanistan  2016     2057.062164
# 4     Afghanistan  2015     2068.265904
# ...           ...   ...             ...
# 6863     Zimbabwe  1994     3263.934978
# 6864     Zimbabwe  1993     3033.504852
# 6865     Zimbabwe  1992     3054.889178
# 6866     Zimbabwe  1991     3426.598094
# 6867     Zimbabwe  1990     3324.348171
#
# [6868 rows x 3 columns]

# %%
#Ques 9 Create a new dataframe by subsetting `gdp_df` to just the year 2014. Call this new dataframe `gdp_2014`.

gdp_2014 = gdp_df[gdp_df["Year"] == 2014]
print(gdp_2014)
# Out:
#                   Country  Year  GDP_Per_Capita
# 5             Afghanistan  2014     2102.385234
# 23                Albania  2014    11623.866679
# 53                Algeria  2014    11512.705405
# 83                 Angola  2014     8239.828837
# 113   Antigua and Barbuda  2014    18104.241470
# ...                   ...   ...             ...
# 6727              Vietnam  2014     6098.489609
# 6757   West Bank and Gaza  2014     5967.073437
# 6783                World  2014    15189.648507
# 6813               Zambia  2014     3450.046561
# 6843             Zimbabwe  2014     2955.240287
#
# [238 rows x 3 columns]

# %%
#Ques 10. Use `.describe()` to find the summary statistics for GDP per capita in 2014. 
gdp_2014.describe()
# Out:
#          Year  GDP_Per_Capita
# count   238.0      238.000000
# mean   2014.0    19766.710348
# std       0.0    20983.869623
# min    2014.0      822.610458
# 25%    2014.0     4753.110934
# 50%    2014.0    12209.385755
# 75%    2014.0    26803.610474
# max    2014.0   156514.133850

# %%
#Ques . Create a histogram of GDP Per Capita numbers for 2014 (you may wish to adjust the number of bins for your histogram). 
#How would you describe the shape of the distribution?
gdp_2014.hist(column="GDP_Per_Capita", bins=50, figsize=(20,12))
# Out:
# array([[<AxesSubplot:title={'center':'GDP_Per_Capita'}>]], dtype=object)

# %%
#Ques 12. Find the top 5 counties and bottom 5 countries by GDP per capita in 2014.
gdp_2014.sort_values(["GDP_Per_Capita"],ascending=[False])
# Out:
#                        Country  Year  GDP_Per_Capita
# 3721          Macao SAR, China  2014   156514.133850
# 3691                Luxembourg  2014   108760.916030
# 5138                     Qatar  2014    95578.416973
# 5464                 Singapore  2014    87808.663157
# 561                    Bermuda  2014    77361.104881
# ...                        ...   ...             ...
# 4528                     Niger  2014     1127.615541
# 1422           Dem. Rep. Congo  2014     1029.790785
# 3781                    Malawi  2014     1027.208496
# 827                    Burundi  2014      886.235777
# 1047  Central African Republic  2014      822.610458
#
# [238 rows x 3 columns]

# %%
# Ques 13. Now, return to the full dataset, `gdp_df`. 
#Pivot the data for 1990 and 2017 (using the pandas `.pivot_table()` method or another method) so that each row corresponds 
#to a country, each column corresponds to a year, and the values in the table give the GDP_Per_Capita amount. 
#Drop any rows that are missing values for either 1990 or 2017. Save the result to a dataframe named `gdp_pivoted`.

gdp_pivoted = gdp_df[(gdp_df["Year"] >= 1990) & (gdp_df["Year"] <= 2017 )]

# %%
gdp_pivoted = gdp_pivoted.pivot(index='Country', columns='Year', values='GDP_Per_Capita')

# %%
gdp_pivoted
# Out:
# Year                         1990          1991          1992          1993  \
# Country
# Afghanistan                   NaN           NaN           NaN           NaN
# Albania               4842.734635   3507.746654   3275.444336   3610.520633
# Algeria               8746.352901   8431.385028   8383.770248   8027.376688
# Angola                5783.429064   5649.782130   5148.252824   3788.508107
# Antigua and Barbuda  15459.551675  15586.896172  15497.464744  15991.764201
# ...                           ...           ...           ...           ...
# Vietnam               1673.249634   1736.014139   1847.620675   1957.644497
# West Bank and Gaza            NaN           NaN           NaN           NaN
# World                 9680.269697   9645.256163   9647.070526   9657.888486
# Zambia                2190.182814   2133.689042   2045.973257   2133.263108
# Zimbabwe              3324.348171   3426.598094   3054.889178   3033.504852
#
# ...

# %%
gdp_pivoted = gdp_pivoted.dropna(axis=0)
gdp_pivoted.shape
gdp_pivoted
# Out:
# Year                         1990          1991          1992          1993  \
# Country
# Albania               4842.734635   3507.746654   3275.444336   3610.520633
# Algeria               8746.352901   8431.385028   8383.770248   8027.376688
# Angola                5783.429064   5649.782130   5148.252824   3788.508107
# Antigua and Barbuda  15459.551675  15586.896172  15497.464744  15991.764201
# Arab World            9694.667544   9651.626577   9933.531454   9927.649928
# ...                           ...           ...           ...           ...
# Vanuatu               2888.309393   2897.327707   2886.920558   2824.882319
# Vietnam               1673.249634   1736.014139   1847.620675   1957.644497
# World                 9680.269697   9645.256163   9647.070526   9657.888486
# Zambia                2190.182814   2133.689042   2045.973257   2133.263108
# Zimbabwe              3324.348171   3426.598094   3054.889178   3033.504852
#
# ...

# %%
#Ques 14. Create a new column in `gdp_pivoted` named `Percent_Change`. 
#This column should contain the percent change in GDP_Per_Capita from 1990 to 2017. 
#Hint: Percent change is calculated as 100*(New Value - Old Value) / Old Value.

gdp_pivoted["Percent_Change"] = 100 * ((gdp_pivoted[2017] - gdp_pivoted[1990])/gdp_pivoted[1990])
# Out:
# C:\Users\kalea\AppData\Local\Temp\ipykernel_23252\1351179099.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_pivoted["Percent_Change"] = 100 * ((gdp_pivoted[2017] - gdp_pivoted[1990])/gdp_pivoted[1990])

# %%
gdp_pivoted
# Out:
# Year                         1990          1991          1992          1993  \
# Country
# Albania               4842.734635   3507.746654   3275.444336   3610.520633
# Algeria               8746.352901   8431.385028   8383.770248   8027.376688
# Angola                5783.429064   5649.782130   5148.252824   3788.508107
# Antigua and Barbuda  15459.551675  15586.896172  15497.464744  15991.764201
# Arab World            9694.667544   9651.626577   9933.531454   9927.649928
# ...                           ...           ...           ...           ...
# Vanuatu               2888.309393   2897.327707   2886.920558   2824.882319
# Vietnam               1673.249634   1736.014139   1847.620675   1957.644497
# World                 9680.269697   9645.256163   9647.070526   9657.888486
# Zambia                2190.182814   2133.689042   2045.973257   2133.263108
# Zimbabwe              3324.348171   3426.598094   3054.889178   3033.504852
#
# ...

# %%
# Ques 15. How many countries experienced a negative percent change in GDP per capita from 1990 to 2017?
print(gdp_pivoted["Percent_Change"].sort_values().to_string())

#Answer : 17
gdp_pivoted[gdp_pivoted["Percent_Change"] < 0]
# Out:
# Country
# Dem. Rep. Congo                                       -41.759785
# United Arab Emirates                                  -39.720953
# Burundi                                               -34.710993
# Ukraine                                               -24.636028
# Central African Republic                              -24.039332
# Tajikistan                                            -20.147445
# Gabon                                                 -17.451209
# Congo                                                 -16.439488
# Madagascar                                            -14.496571
# Brunei                                                -14.369026
# Zimbabwe                                               -8.907075
# The Gambia                                             -8.501789
# Haiti                                                  -7.699292
# The Bahamas                                            -4.731099
# ...

# %%
gdp_pivoted_PerChange = gdp_pivoted[gdp_pivoted["Percent_Change"] < 0]
gdp_pivoted_PerChange["Percent_Change"].sort_values()
# Out:
# Country
# Dem. Rep. Congo            -41.759785
# United Arab Emirates       -39.720953
# Burundi                    -34.710993
# Ukraine                    -24.636028
# Central African Republic   -24.039332
# Tajikistan                 -20.147445
# Gabon                      -17.451209
# Congo                      -16.439488
# Madagascar                 -14.496571
# Brunei                     -14.369026
# Zimbabwe                    -8.907075
# The Gambia                  -8.501789
# Haiti                       -7.699292
# The Bahamas                 -4.731099
# Guinea-Bissau               -3.480873
# Kyrgyz Republic             -2.164001
# Comoros                     -0.950753
# Name: Percent_Change, dtype: float64

# %%
# Ques 16. Which country had the highest % change in GDP per capita? Create a line plot showing this country's GDP per capita for all years from 1990 to 2017. Create another showing the country with the second highest % change in GDP. How do the trends in these countries compare?  
# **Bonus:** Put both line charts on the same plot.

gdp_pivoted.sort_values(by='Percent_Change', ascending=False)


# Ques 16 ANSWERS. 
# A Which country had the highest % change in GDP per capita? = Equatorial Guinea
# Out:
# Year                                                  1990           1991  \
# Country
# Equatorial Guinea                              1039.985049     996.857617
# China                                          1423.896348    1534.705272
# Myanmar                                         619.645144     607.457440
# East Asia & Pacific (excluding high income)    2173.223895    2303.744681
# East Asia & Pacific (IDA & IBRD)               2196.950288    2328.906789
# ...                                                    ...            ...
# Central African Republic                       1201.677234    1165.239450
# Ukraine                                       15751.722440   14396.632702
# Burundi                                        1184.842440    1215.886531
# United Arab Emirates                         111454.360446  106103.881293
# Dem. Rep. Congo                                1819.723315    1606.326515
#
# ...

# %%
# 16 B Create a line plot showing this country's GDP per capita for all years from 1990 to 2017. 
#print(gdp_EqGuinea)
gdp_EqGuinea = gdp_pivoted.loc[('Equatorial Guinea')]
gdp_EqGuinea = gdp_EqGuinea.to_frame()
gdp_EqGuinea= gdp_EqGuinea.reset_index()
gdp_EqGuinea = gdp_EqGuinea.drop(28)
#gdp_EqGuinea =gdp_EqGuinea.iloc[:, :]
#gdp_EqGuinea = gdp_EqGuinea.loc[:, 'Year':' Equatorial Guinea']

#gdp_EqGuinea.plot(kind = 'line', figsize=(10, 10))

# %%
gdp_EqGuinea.plot(kind = 'line', x="Year")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:6982: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   return Index(sequences[0], name=names)
# <AxesSubplot:xlabel='Year'>

# %%
# 16 C Create another showing the country with the second highest % change in GDP. 
# China

gdp_China = gdp_pivoted.loc[('China')]
gdp_China = gdp_China.to_frame()
gdp_China= gdp_China.reset_index()

gdp_China = gdp_China.drop(28)
gdp_China.loc[:,["Year", "China"]].plot("Year", "China")

#gdp_China.plot(kind = 'line',  figsize=(10, 10))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:6982: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   return Index(sequences[0], name=names)
# <AxesSubplot:xlabel='Year'>

# %%
# 16 D How do the trends in these countries compare?  
#ANSER: Dropped for Equatorial Guinea after where as china has it going up

# %%
#QUES 16 E **Bonus:** Put both line charts on the same plot

# %%
# 17. Read in continents.csv contained in the `data` folder into a new dataframe called `continents`.
# We will be using this dataframe to add a new column to our dataset.
continents = pd.read_csv("../data/continents.csv")
continents
# Out:
#     Continent             Country
# 0        Asia         Afghanistan
# 1      Europe             Albania
# 2      Africa             Algeria
# 3      Europe             Andorra
# 4      Africa              Angola
# ..        ...                 ...
# 211      Asia             Vietnam
# 212      Asia  West Bank and Gaza
# 213      Asia               Yemen
# 214    Africa              Zambia
# 215    Africa            Zimbabwe
#
# [216 rows x 2 columns]

# %%
#QUES 18 Merge gdp_df and continents. 
#Keep only the countries that appear in both data frames. Save the result back to gdp_df.
gdp_df.head(5)
# Out:
#        Country  Year  GDP_Per_Capita
# 0  Afghanistan  2019     2065.036398
# 1  Afghanistan  2018     2033.779002
# 2  Afghanistan  2017     2058.383832
# 3  Afghanistan  2016     2057.062164
# 4  Afghanistan  2015     2068.265904

# %%
continents.head(5)
# Out:
#   Continent      Country
# 0      Asia  Afghanistan
# 1    Europe      Albania
# 2    Africa      Algeria
# 3    Europe      Andorra
# 4    Africa       Angola

# %%
gdp_df = pd.merge(left=gdp_df.rename(columns={"Country or Area": "Country"}), 
         right=continents
        )

# %%
#QUES 19 Determine the number of countries per continent. Create a bar chart showing this.
gdp_df
#gdp_df.groupby(['Continent'])['Continent'].count()
# Out:
#           Country  Year  GDP_Per_Capita Continent
# 0     Afghanistan  2019     2065.036398      Asia
# 1     Afghanistan  2018     2033.779002      Asia
# 2     Afghanistan  2017     2058.383832      Asia
# 3     Afghanistan  2016     2057.062164      Asia
# 4     Afghanistan  2015     2068.265904      Asia
# ...           ...   ...             ...       ...
# 5438     Zimbabwe  1994     3263.934978    Africa
# 5439     Zimbabwe  1993     3033.504852    Africa
# 5440     Zimbabwe  1992     3054.889178    Africa
# 5441     Zimbabwe  1991     3426.598094    Africa
# 5442     Zimbabwe  1990     3324.348171    Africa
#
# [5443 rows x 4 columns]

# %%
gdp_df.groupby(['Continent'])['Continent'].count().plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='Continent'>

# %%
gdp_df
# Out:
#           Country  Year  GDP_Per_Capita Continent
# 0     Afghanistan  2019     2065.036398      Asia
# 1     Afghanistan  2018     2033.779002      Asia
# 2     Afghanistan  2017     2058.383832      Asia
# 3     Afghanistan  2016     2057.062164      Asia
# 4     Afghanistan  2015     2068.265904      Asia
# ...           ...   ...             ...       ...
# 5438     Zimbabwe  1994     3263.934978    Africa
# 5439     Zimbabwe  1993     3033.504852    Africa
# 5440     Zimbabwe  1992     3054.889178    Africa
# 5441     Zimbabwe  1991     3426.598094    Africa
# 5442     Zimbabwe  1990     3324.348171    Africa
#
# [5443 rows x 4 columns]

# %%
#QUES 20 Create a seaborn boxplot showing GDP per capita in 2014 split out by continent. What do you notice?
gdp_df[gdp_df["Year"] == 2014]

gdp_df.groupby("Continent")['Country'].unique()
gdp_df.head(20)
# Out:
#         Country  Year  GDP_Per_Capita Continent
# 0   Afghanistan  2019     2065.036398      Asia
# 1   Afghanistan  2018     2033.779002      Asia
# 2   Afghanistan  2017     2058.383832      Asia
# 3   Afghanistan  2016     2057.062164      Asia
# 4   Afghanistan  2015     2068.265904      Asia
# 5   Afghanistan  2014     2102.385234      Asia
# 6   Afghanistan  2013     2116.465454      Asia
# 7   Afghanistan  2012     2075.491747      Asia
# 8   Afghanistan  2011     1904.559799      Asia
# 9   Afghanistan  2010     1957.029338      Asia
# 10  Afghanistan  2009     1758.904043      Asia
# 11  Afghanistan  2008     1484.114729      Asia
# 12  Afghanistan  2007     1460.826075      Asia
# 13  Afghanistan  2006     1315.789565      Asia
# 14  Afghanistan  2005     1286.793508      Asia
# 15  Afghanistan  2004     1200.278256      Asia
# 16  Afghanistan  2003     1235.810063      Asia
# 17  Afghanistan  2002     1189.784878      Asia
# 18      Albania  2019    13724.058790    Europe
# ...

# %%
df1= gdp_df[gdp_df["Year"] == 2014]
df1
df2 = df1[["GDP_Per_Capita", "Continent"]]
df2
df2.boxplot(by ="Continent")
#gdp_df.loc[ :, gdp_df["Year"] == "2014",["Value", "Continent"]]
# Out:
# <AxesSubplot:title={'center':'GDP_Per_Capita'}, xlabel='[Continent]'>

# %%
#QUES 21. Download the full csv containing Life expectancy at birth, total (years) 
#from [https://data.worldbank.org/indicator/SP.DYN.LE00.IN?name_desc=false]
#(https://data.worldbank.org/indicator/SP.DYN.LE00.IN?name_desc=false). 
#Read this data into a DataFrame named `life_expectancy`.

#Cleanup - skip first few junk rows
life_expectancy = pd.read_csv('../data/API_SP.DYN.LE00.IN_DS2_en_csv_v2_4558314.csv', skiprows=4)

# %%
#QUES 22. A. Drop the Country Code, Indicator Name, and Indicator Code columns. 
# B. Then use `.melt()` to convert your data from wide to long. 
#    That is, instead of having one row per country and multiple colums per year, 
#    we want to have multiple rows per country and a single column for year. 
# C After melting, rename the columns to `Country`, `Year`, and `Life_Expectancy`.

life_expectancy
# Out:
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
#                               Indicator Name  Indicator Code       1960  \
# 0    Life expectancy at birth, total (years)  SP.DYN.LE00.IN  65.662000
# 1    Life expectancy at birth, total (years)  SP.DYN.LE00.IN  42.716053
# 2    Life expectancy at birth, total (years)  SP.DYN.LE00.IN  32.446000
# 3    Life expectancy at birth, total (years)  SP.DYN.LE00.IN  37.205380
# ...

# %%
life_expectancy = life_expectancy.drop(['Country Code', 'Indicator Name', 'Indicator Code'], axis=1)
life_expectancy
# Out:
#                     Country Name       1960       1961       1962       1963  \
# 0                          Aruba  65.662000  66.074000  66.444000  66.787000
# 1    Africa Eastern and Southern  42.716053  43.166935  43.603990  44.025617
# 2                    Afghanistan  32.446000  32.962000  33.471000  33.971000
# 3     Africa Western and Central  37.205380  37.632546  38.052612  38.463746
# 4                         Angola  37.524000  37.811000  38.113000  38.430000
# ..                           ...        ...        ...        ...        ...
# 261                       Kosovo        NaN        NaN        NaN        NaN
# 262                  Yemen, Rep.  29.919000  30.163000  30.500000  30.943000
# 263                 South Africa  48.406000  48.777000  49.142000  49.509000
# 264                       Zambia  46.687000  47.084000  47.446000  47.772000
# 265                     Zimbabwe  53.019000  53.483000  53.946000  54.403000
#
# ...

# %%
life_expectancy = life_expectancy.drop(['2021', 'Unnamed: 66'], axis=1)
life_expectancy
# Out:
#                     Country Name       1960       1961       1962       1963  \
# 0                          Aruba  65.662000  66.074000  66.444000  66.787000
# 1    Africa Eastern and Southern  42.716053  43.166935  43.603990  44.025617
# 2                    Afghanistan  32.446000  32.962000  33.471000  33.971000
# 3     Africa Western and Central  37.205380  37.632546  38.052612  38.463746
# 4                         Angola  37.524000  37.811000  38.113000  38.430000
# ..                           ...        ...        ...        ...        ...
# 261                       Kosovo        NaN        NaN        NaN        NaN
# 262                  Yemen, Rep.  29.919000  30.163000  30.500000  30.943000
# 263                 South Africa  48.406000  48.777000  49.142000  49.509000
# 264                       Zambia  46.687000  47.084000  47.446000  47.772000
# 265                     Zimbabwe  53.019000  53.483000  53.946000  54.403000
#
# ...

# %%
life_expectancy = pd.melt(life_expectancy, id_vars = ['Country Name'])

# %%
life_expectancy
# Out:
#                       Country Name variable      value
# 0                            Aruba     1960  65.662000
# 1      Africa Eastern and Southern     1960  42.716053
# 2                      Afghanistan     1960  32.446000
# 3       Africa Western and Central     1960  37.205380
# 4                           Angola     1960  37.524000
# ...                            ...      ...        ...
# 16221                       Kosovo     2020  71.087805
# 16222                  Yemen, Rep.     2020  66.181000
# 16223                 South Africa     2020  64.379000
# 16224                       Zambia     2020  64.194000
# 16225                     Zimbabwe     2020  61.738000
#
# [16226 rows x 3 columns]

# %%
 #22 C After melting, rename the columns to `Country`, "variable": "Year", and `Life_Expectancy`.
life_expectancy = life_expectancy.rename(columns= {"Country Name": "Country", "variable":"Year", "value":"Life_Expectancy"})
life_expectancy
# Out:
#                            Country  Year  Life_Expectancy
# 0                            Aruba  1960        65.662000
# 1      Africa Eastern and Southern  1960        42.716053
# 2                      Afghanistan  1960        32.446000
# 3       Africa Western and Central  1960        37.205380
# 4                           Angola  1960        37.524000
# ...                            ...   ...              ...
# 16221                       Kosovo  2020        71.087805
# 16222                  Yemen, Rep.  2020        66.181000
# 16223                 South Africa  2020        64.379000
# 16224                       Zambia  2020        64.194000
# 16225                     Zimbabwe  2020        61.738000
#
# [16226 rows x 3 columns]

# %%
#AK 16753	Kosovo	Unnamed: 66	NaN
#life_expectancy
#Unnamed: 66
life_expectancy= life_expectancy[life_expectancy['Year'] != "Unnamed: 66"]
life_expectancy
# Out:
#                            Country  Year  Life_Expectancy
# 0                            Aruba  1960        65.662000
# 1      Africa Eastern and Southern  1960        42.716053
# 2                      Afghanistan  1960        32.446000
# 3       Africa Western and Central  1960        37.205380
# 4                           Angola  1960        37.524000
# ...                            ...   ...              ...
# 16221                       Kosovo  2020        71.087805
# 16222                  Yemen, Rep.  2020        66.181000
# 16223                 South Africa  2020        64.379000
# 16224                       Zambia  2020        64.194000
# 16225                     Zimbabwe  2020        61.738000
#
# [16226 rows x 3 columns]

# %%
# Ques 23. What was the first country with a life expectancy to exceed 80?
#life_expectancy.sort_values(by=["Life_Expectancy"], ascending=False)

life_expectancy= life_expectancy[life_expectancy['Year'] != "2021"]

# %%
life_expectancy = life_expectancy.astype({'Year': int})

# %%
life_expectancy_80 = life_expectancy[life_expectancy["Life_Expectancy"] > 80].sort_values(by=["Life_Expectancy"], ascending=True)
#life_expectancy_80.sort_values(by=["Life_Expectancy"], ascending=True)

# %%
#Ques 23. Answer = OECD members

# %%
life_expectancy_80
# Out:
#                     Country  Year  Life_Expectancy
# 15343          OECD members  2017        80.005170
# 13051               Belgium  2009        80.034146
# 12147                Norway  2005        80.041463
# 15467                 Chile  2018        80.042000
# 11742       Channel Islands  2004        80.045000
# ...                     ...   ...              ...
# 16079                 Japan  2020        84.615610
# 15258  Hong Kong SAR, China  2017        84.680488
# 15524  Hong Kong SAR, China  2018        84.934146
# 15790  Hong Kong SAR, China  2019        85.078049
# 16056  Hong Kong SAR, China  2020        85.387805
#
# [562 rows x 3 columns]

# %%
#QUES 24. Merge `gdp_per_capita` and `life_expectancy`, keeping all countries and years that appear in both DataFrames. 
#Save the result to a new DataFrame named `gdp_le`. If you get any errors in doing this, read them carefully and correct them. Look at the first five rows of your new data frame to confirm it merged correctly. 
#Also, check the last five rows to make sure the data is clean and as expected.

gdp_le = pd.merge(gdp_df.dropna(), life_expectancy.dropna())
gdp_le
# Out:
#           Country  Year  GDP_Per_Capita Continent  Life_Expectancy
# 0     Afghanistan  2019     2065.036398      Asia           64.833
# 1     Afghanistan  2018     2033.779002      Asia           64.486
# 2     Afghanistan  2017     2058.383832      Asia           64.130
# 3     Afghanistan  2016     2057.062164      Asia           63.763
# 4     Afghanistan  2015     2068.265904      Asia           63.377
# ...           ...   ...             ...       ...              ...
# 4917     Zimbabwe  1994     3263.934978    Africa           52.044
# 4918     Zimbabwe  1993     3033.504852    Africa           53.653
# 4919     Zimbabwe  1992     3054.889178    Africa           55.243
# 4920     Zimbabwe  1991     3426.598094    Africa           56.749
# 4921     Zimbabwe  1990     3324.348171    Africa           58.100
#
# [4922 rows x 5 columns]

# %%
#QUES 25. 
# A. Create a new DataFrame, named `gdp_le_2019` by extracting data for the year 2019 from `gdp_le`. 
# B. How many countries have a life expectancy of at least 80 in 2019?
gdp_le_2019 = gdp_le[gdp_le["Year"] == 2019]

# %%
# 25 B. How many countries have a life expectancy of at least 80 in 2019?

#ANS = 33
len(gdp_le_2019[gdp_le_2019["Life_Expectancy"] >= 80])
# Out:
# 33

# %%
#QUES 26. A. Find the countries that had the top 3 largest GDP per capita figures for 2019. 
# B. Create a seaborn FacetGrid showing the change in life expectancy over time for these three countries. 
# C. Each individual figure in the facet grid will represent a single country.

#Ans A.
gdp_le_2019_top3 = gdp_le_2019.sort_values(by=["GDP_Per_Capita"], ascending=False).head(3)
gdp_le_2019_top3
# Out:
#                Country  Year  GDP_Per_Capita Continent  Life_Expectancy
# 2628  Macao SAR, China  2019   123965.286432      Asia        84.244000
# 2598        Luxembourg  2019   114304.044210    Europe        82.639024
# 3916         Singapore  2019    97341.468645      Asia        83.595122

# %%
# 26 B. Create a seaborn FacetGrid showing the change in life expectancy over time for these three countries. 
# C. Each individual figure in the facet grid will represent a single country.


gdp_le_Top3 = gdp_le[gdp_le["Country"].isin(["Macao SAR, China","Luxembourg","Singapore"])]
g = sns.FacetGrid(gdp_le_Top3, col="Country")
g.map(sns.scatterplot, "Year", "Life_Expectancy")

# %%
#QUES 27. Create a scatter plot of Life Expectancy vs GDP per Capita for the year 2019. 
# What do you notice? - Life Expectancy icreases with GDP
gdp_le_2019
plt.scatter(gdp_le_2019.Life_Expectancy, gdp_le_2019.GDP_Per_Capita)

# %%
#QUES 28. Find the correlation between Life Expectancy and GDP per Capita for the year 2019. 
# What is the meaning of this number? --> Positive association between the 2 variables
gdp_le_2019["Life_Expectancy"].corr(gdp_le_2019["GDP_Per_Capita"])
# Out:
# 0.7090182746006474

# %%
# QUES 29. Add a column to `gdp_le_2019` and calculate the logarithm of GDP per capita. 
# Find the correlation between the log of GDP per capita and life expectancy. 
# How does this compare to the calculation in the previous part? 
# Look at a scatter plot to see if the result of this calculation makes sense.
